# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('/content/AAPL_historical_data.csv')

# %%
df.head()
# Out:
#                         Date      Open      High       Low     Close
# 0  1980-12-12 00:00:00-05:00  0.098834  0.099264  0.098834  0.098834
# 1  1980-12-15 00:00:00-05:00  0.094108  0.094108  0.093678  0.093678
# 2  1980-12-16 00:00:00-05:00  0.087232  0.087232  0.086802  0.086802
# 3  1980-12-17 00:00:00-05:00  0.088951  0.089381  0.088951  0.088951
# 4  1980-12-18 00:00:00-05:00  0.091530  0.091959  0.091530  0.091530

# %%
df.tail()
# Out:
#                             Date        Open        High         Low  \
# 11089  2024-12-09 00:00:00-05:00  241.830002  247.240005  241.750000
# 11090  2024-12-10 00:00:00-05:00  246.889999  248.210007  245.339996
# 11091  2024-12-11 00:00:00-05:00  247.960007  250.800003  246.259995
# 11092  2024-12-12 00:00:00-05:00  246.889999  248.740005  245.679993
# 11093  2024-12-13 00:00:00-05:00  247.820007  249.289993  246.240005
#
#             Close
# 11089  246.750000
# 11090  247.770004
# 11091  246.490005
# 11092  247.960007
# 11093  248.130005

# %%
df.isnull().sum()
# Out:
# Date     0
# Open     0
# High     0
# Low      0
# Close    0
# dtype: int64

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.isnull())
plt.show()

# %%
df.shape
# Out:
# (11094, 5)

# %%
plt.figure(figsize=(7,7))
plt.stem(list(df['Open'].value_counts().keys()))
plt.xlabel('Quantity Time')
plt.ylabel('Price Of Open Share')
plt.title('Open Share Price Time')
plt.show()

# %%
plt.figure(figsize=(7,7))
plt.stem(list(df['Close'].value_counts().keys()))
plt.xlabel('Quantity Time')
plt.ylabel('Price Of Close Share')
plt.title('Close Share Price Time')
plt.show()

# %%
df.plot(subplots=True, figsize=(20,12))
plt.show()

# %%
df.describe()
# Out:
#                Open          High           Low         Close
# count  11094.000000  11094.000000  11094.000000  11094.000000
# mean      23.236654     23.484468     23.001626     23.254564
# std       49.129620     49.645173     48.654514     49.178271
# min        0.038245      0.038245      0.037815      0.037815
# 25%        0.242896      0.248067      0.237920      0.242953
# 50%        0.442782      0.451501      0.435876      0.444634
# 75%       18.083088     18.278464     17.904287     18.107803
# max      247.960007    250.800003    246.259995    248.130005

# %%
df.hist(figsize=(14, 8))
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='High', y='Low', data=df)
plt.legend()
plt.show()
# Out:
# <ipython-input-34-2537997182>:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Open', y='Close', data=df)
plt.legend()
plt.show()
# Out:
# <ipython-input-35-3140607965>:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
